# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline

# %%
df = pd.read_excel('houston_pollen.xlsx', sheet_name='2021', parse_dates=['date'])
df.head()
# Out:
#         date month  Alnus(Alder)   Ash  Black Walnut  Bushes  Birch  Cedar  \
# 0 2021-01-01   Jan            64     4             0       0      0   3846
# 1 2021-02-01   Feb            20   190             0       0     40   2964
# 2 2021-03-01   Mar             6  1113            18       0    158    434
# 3 2021-04-01   Apr             2   538            12       0     80    108
# 4 2021-05-01   May             0    10             0       0      2      6
#
#    Cotton Wood  Dogwood  ...  Plantago(plantain)  Ragweed  Rumex  Sagebrush  \
# 0            0        0  ...                   0       24      0          0
# 1            0        0  ...                   0        0      0          0
# 2          122        0  ...                   0        0      8          0
# 3           10        0  ...                  12        0     48          0
# 4            0        0  ...                  88        0     14          0
#
# ...

# %%
plt.figure(figsize=(15,12))
plt.plot(df['month'], df['Pollen Total'], c='black', lw=4, label='Pollen Total')
plt.plot(df['month'], df['Tree Total'], c='b', lw=2, label='Tree Total')
plt.plot(df['month'], df['Grass Total'], c='r', lw=2, label='Grass Total')
plt.plot(df['month'], df['Weed Total'], c='orange', lw=2, label='Weed Total')
plt.xlabel('Month', fontsize=20)
plt.ylabel('Pollen Count', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=20)
plt.title('Houston Pollen Count in 2021', fontsize=20)

ax = plt.gca()
fmt = "{x:,.0f}"
tick = mpl.ticker.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

plt.savefig('houston_pollen_total_2021_lineplot.png')

# %%
plt.figure(figsize=(15,12))
plt.bar(df['month'], df['Tree Total'], label='Tree Total', color='darkblue')
plt.bar(df['month'], df['Grass Total'], label='Grass Total', bottom=df['Tree Total'], color='red')
plt.bar(df['month'], df['Weed Total'], label='Weed Total', bottom=df['Tree Total']+df['Grass Total'], color='orange')
plt.legend(fontsize=20)
plt.xlabel('Month', fontsize=20)
plt.ylabel('Pollen Count', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('Houston Pollen Count in 2021', fontsize=20)

ax = plt.gca()
fmt = "{x:,.0f}"
tick = mpl.ticker.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

plt.savefig('houston_pollen_total_2021_barplot.png')

# %%
df_total = pd.read_excel('houston_pollen.xlsx', sheet_name='2021_total')

df_total_may = df_total[['pollen', 'May']][df_total['May'] > 0]
df_total_jun = df_total[['pollen', 'Jun']][df_total['Jun'] > 0]
df_total_jul = df_total[['pollen', 'Jul']][df_total['Jul'] > 0]
df_total_aug = df_total[['pollen', 'Aug']][df_total['Aug'] > 0]

colors = ("skyblue", "orange", "beige", "grey", "lightgreen", "indigo", "red", "black")
wp = {'linewidth' : 1, 'edgecolor' : "green"}

fig, ax = plt.subplots(nrows=2, ncols=2, figsize =(12, 12))

wedges, texts, autotexts = ax[0,0].pie(df_total_may['May'], labels = df_total_may['pollen'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,0].set_title('Contribution of Pollen Count in May', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[0,1].pie(df_total_jun['Jun'], labels = df_total_jun['pollen'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,1].set_title('Contribution of Pollen Count in June', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,0].pie(df_total_jul['Jul'], labels = df_total_jul['pollen'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,0].set_title('Contribution of Pollen Count in July', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,1].pie(df_total_aug['Aug'], labels = df_total_aug['pollen'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,1].set_title('Contribution of Pollen Count in August', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")
plt.tight_layout()

plt.savefig('contribution_pollen_total_may_june_july_august.png')

# %%
df_total_sep = df_total[['pollen', 'Sep']][df_total['Sep'] > 0]
df_total_oct = df_total[['pollen', 'Oct']][df_total['Oct'] > 0]
df_total_nov = df_total[['pollen', 'Nov']][df_total['Nov'] > 0]
df_total_dec = df_total[['pollen', 'Dec']][df_total['Dec'] > 0]

colors = ("skyblue", "orange", "beige", "grey", "lightgreen", "indigo", "red", "black")
wp = {'linewidth' : 1, 'edgecolor' : "green"}

fig, ax = plt.subplots(nrows=2, ncols=2, figsize =(12, 12))

wedges, texts, autotexts = ax[0,0].pie(df_total_sep['Sep'], labels = df_total_sep['pollen'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,0].set_title('Contribution of Pollen Count in September', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[0,1].pie(df_total_oct['Oct'], labels = df_total_oct['pollen'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,1].set_title('Contribution of Pollen Count in October', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,0].pie(df_total_nov['Nov'], labels = df_total_nov['pollen'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,0].set_title('Contribution of Pollen Count in November', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,1].pie(df_total_dec['Dec'], labels = df_total_dec['pollen'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,1].set_title('Contribution of Pollen Count in December', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")
plt.tight_layout()

plt.savefig('contribution_pollen_total_sep_oct_nov_dec.png')

# %%
df_tree = pd.read_excel('houston_pollen.xlsx', sheet_name='2021_tree')

df_tree_jan = df_tree[['tree', 'Jan']][df_tree['Jan'] > 0]
df_tree_feb = df_tree[['tree', 'Feb']][df_tree['Feb'] > 0]
df_tree_mar = df_tree[['tree', 'Mar']][df_tree['Mar'] > 0]
df_tree_apr = df_tree[['tree', 'Apr']][df_tree['Apr'] > 0]

colors = ("skyblue", "orange", "beige", "grey", "lightgreen", "indigo", "red", "black")
wp = {'linewidth' : 1, 'edgecolor' : "green"}

fig, ax = plt.subplots(nrows=2, ncols=2, figsize =(12, 12))

wedges, texts, autotexts = ax[0,0].pie(df_tree_jan['Jan'], labels = df_tree_jan['tree'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,0].set_title('Contribution of Trees in January', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[0,1].pie(df_tree_feb['Feb'], labels = df_tree_feb['tree'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,1].set_title('Contribution of Trees in Feburary', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,0].pie(df_tree_mar['Mar'], labels = df_tree_mar['tree'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,0].set_title('Contribution of Trees in March', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,1].pie(df_tree_apr['Apr'], labels = df_tree_apr['tree'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,1].set_title('Contribution of Trees in April', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")
plt.tight_layout()

plt.savefig('contribution_tree_total_jan_feb_mar_apr.png')

# %%
df_tree_may = df_tree[['tree', 'May']][df_tree['May'] > 0]
df_tree_sep = df_tree[['tree', 'Sep']][df_tree['Sep'] > 0]
df_tree_oct = df_tree[['tree', 'Oct']][df_tree['Oct'] > 0]
df_tree_dec = df_tree[['tree', 'Dec']][df_tree['Dec'] > 0]

colors = ("skyblue", "orange", "beige", "grey", "lightgreen", "indigo", "red", "black")
wp = {'linewidth' : 1, 'edgecolor' : "green"}

fig, ax = plt.subplots(nrows=2, ncols=2, figsize =(12, 12))

wedges, texts, autotexts = ax[0,0].pie(df_tree_may['May'], labels = df_tree_may['tree'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,0].set_title('Contribution of Trees in May', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[0,1].pie(df_tree_sep['Sep'], labels = df_tree_sep['tree'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,1].set_title('Contribution of Trees in September', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,0].pie(df_tree_oct['Oct'], labels = df_tree_oct['tree'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,0].set_title('Contribution of Trees in October', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,1].pie(df_tree_dec['Dec'], labels = df_tree_dec['tree'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,1].set_title('Contribution of Trees in December', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")
plt.tight_layout()

plt.savefig('contribution_tree_total_may_sep_oct_dec.png')

# %%
df_weed = pd.read_excel('houston_pollen.xlsx', sheet_name='2021_weed')

df_weed_apr = df_weed[['weed', 'Apr']][df_weed['Apr'] > 0]
df_weed_may = df_weed[['weed', 'May']][df_weed['May'] > 0]
df_weed_jun = df_weed[['weed', 'Jun']][df_weed['Jun'] > 0]
df_weed_jul = df_weed[['weed', 'Jul']][df_weed['Jul'] > 0]

colors = ("skyblue", "orange", "beige", "grey", "lightgreen", "indigo", "red", "black")
wp = {'linewidth' : 1, 'edgecolor' : "green"}

fig, ax = plt.subplots(nrows=2, ncols=2, figsize =(12, 12))

wedges, texts, autotexts = ax[0,0].pie(df_weed_apr['Apr'], labels = df_weed_apr['weed'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,0].set_title('Contribution of Weeds in April', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[0,1].pie(df_weed_may['May'], labels = df_weed_may['weed'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,1].set_title('Contribution of Weeds in May', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,0].pie(df_weed_jun['Jun'], labels = df_weed_jun['weed'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,0].set_title('Contribution of Weeds in June', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,1].pie(df_weed_jul['Jul'], labels = df_weed_jul['weed'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,1].set_title('Contribution of Weeds in July', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")
plt.tight_layout()

plt.savefig('contribution_weed_total_apr_may_jun_jul.png')

# %%
df_weed_aug = df_weed[['weed', 'Aug']][df_weed['Aug'] > 0]
df_weed_sep = df_weed[['weed', 'Sep']][df_weed['Sep'] > 0]
df_weed_oct = df_weed[['weed', 'Oct']][df_weed['Oct'] > 0]
df_weed_nov = df_weed[['weed', 'Nov']][df_weed['Nov'] > 0]

colors = ("skyblue", "orange", "beige", "grey", "lightgreen", "indigo", "red", "black")
wp = {'linewidth' : 1, 'edgecolor' : "green"}

fig, ax = plt.subplots(nrows=2, ncols=2, figsize =(12, 12))

wedges, texts, autotexts = ax[0,0].pie(df_weed_aug['Aug'], labels = df_weed_aug['weed'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,0].set_title('Contribution of Weeds in August', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[0,1].pie(df_weed_sep['Sep'], labels = df_weed_sep['weed'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[0,1].set_title('Contribution of Weeds in September', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,0].pie(df_weed_oct['Oct'], labels = df_weed_oct['weed'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,0].set_title('Contribution of Weeds in October', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")

wedges, texts, autotexts = ax[1,1].pie(df_weed_nov['Nov'], labels = df_weed_nov['weed'], autopct='%1.1f%%', 
                                  colors = colors, startangle = 90, wedgeprops = wp,
                                  textprops = dict(color ="magenta", fontsize=15))

ax[1,1].set_title('Contribution of Weeds in November', fontsize=15)
plt.setp(autotexts, size = 15, weight ="bold")
plt.tight_layout()

plt.savefig('contribution_weed_total_aug_sep_oct_nov.png')
